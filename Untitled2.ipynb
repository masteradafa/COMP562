# %%
# Import TensorFlow and enable eager execution
# This code requires TensorFlow version >=1.9
import tensorflow as tf
tf.enable_eager_execution()

# We'll generate plots of attention in order to see which parts of an image
# our model focuses on during captioning
import matplotlib.pyplot as plt

# Scikit-learn includes many helpful utilities
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

import re
import numpy as np
import os
import time
import json
from glob import glob
from PIL import Image
import pickle

# %%
annotation_zip = tf.keras.utils.get_file('captions.zip', 
                                          cache_subdir=os.path.abspath('.'),
                                          origin = 'http://images.cocodataset.org/annotations/annotations_trainval2014.zip',
                                          extract = True)
annotation_file = os.path.dirname(annotation_zip)+'/annotations/captions_train2014.json'

name_of_zip = 'train2014.zip'
if not os.path.exists(os.path.abspath('.') + '/' + name_of_zip):
  image_zip = tf.keras.utils.get_file(name_of_zip, 
                                      cache_subdir=os.path.abspath('.'),
                                      origin = 'http://images.cocodataset.org/zips/train2014.zip',
                                      extract = True)
  PATH = os.path.dirname(image_zip)+'/train2014/'
else:
  PATH = os.path.abspath('.')+'/train2014/'
# Out:
# Downloading data from http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# 252878848/252872794 [==============================] - 3s 0us/step
# Downloading data from http://images.cocodataset.org/zips/train2014.zip
# 13510574080/13510573713 [==============================] - 219s 0us/step

# %%
with open(annotation_file, 'r') as f:
  annotations = json.load(f)
all_captions = []
all_img_name_vector = []

for annot in annotations['annotations']:
  caption = '<start> ' + annot['caption'] + ' <end>'
  image_id = annot['image_id']
  full_coco_image_path = PATH + 'COCO_train2014_' + '%012d.jpg' % (image_id)
  
  all_img_name_vector.append(full_coco_image_path)
  all_captions.append(caption)

train_captions, img_name_vector = shuffle(all_captions, all_img_name_vector, random_state = 1)

num_example = 50000
train_captions = train_captions[:num_example]
img_name_vector = img_name_vector[:num_example]

# %%
len(train_captions), len(img_name_vector)
# Out:
# (100000, 100000)

# %%
def load_image(image_path):
  img = tf.read_file(image_path)
  img = tf.image.decode_jpeg(img, channels = 3)#color
  img = tf.image.resize_images(img, (299,299))
  img = tf.keras.applications.inception_v3.preprocess_input(img)
  return img, image_path

# %%
image_model = tf.keras.applications.InceptionV3(include_top = False,
                                               weights = 'imagenet')

new_input = image_model.input
hidden_layer = image_model.layers[-1].output

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)

# %%
encode_train = sorted(set(img_name_vector))

image_dataset = tf.data.Dataset.from_tensor_slices(encode_train).map(load_image).batch(16)

# %%
from tqdm import tqdm
for img, path in tqdm(image_dataset):
  batch_features = image_features_extract_model(img)
  batch_features = tf.reshape(batch_features, 
                              (batch_features.shape[0], -1, batch_features.shape[3]))

  for bf, p in zip(batch_features, path):
    path_of_feature = p.numpy().decode("utf-8")
    np.save(path_of_feature, bf.numpy())
# Out:
# 3874it [14:10,  3.22it/s]

# %%
def calc_max_length(tensor):
  return max(len(t) for t in tensor)

# %%
top_k = 5000
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                 oov_token="<unk>",
                                                 filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
tokenizer.fit_on_texts(train_captions)
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
tokenizer.word_index['<pad>'] = 0

# %%
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')

# %%
max_length = calc_max_length(train_seqs)

# %%
img_name_train,img_name_val,cap_train,cap_val = train_test_split(img_name_vector,
                                                                cap_vector,
                                                                test_size=0.2,
                                                                random_state=0)

# %%
len(img_name_train), len(img_name_val), len(cap_train), len(cap_val)
# Out:
# (80000, 20000, 80000, 20000)

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 256
units = 512
vocab_size = len(tokenizer.word_index)
features_shape = 2048
attention_features_shape = 64

# %%
def map_func(img_name, cap):
  img_tensor = np.load(img_name.decode('utf-8')+'.npy')
  return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

dataset = dataset.map(lambda item1, item2: tf.py_func(
    map_func, [item1, item2], [tf.float32, tf.int32]), num_parallel_calls=2)

# %%
dataset = dataset.shuffle(BUFFER_SIZE)

dataset = dataset.batch(BATCH_SIZE)
dataset = dataset.prefetch(1)

# %%
def gru(units):
  if tf.test.is_gpu_available():
    return tf.keras.layers.CuDNNGRU(units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
  else:
    return tf.keras.layers.GRU(units,
                              return_sequences=True,
                              return_state=True,
                              recurrent_activation='sigmoid',
                              recurrent_initializer='glorot_uniform')

# %%
class BahdanauAttention(tf.keras.Model):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)
  def call(self, features, hidden):
    hidden_with_time_axis = tf.expand_dims(hidden, 1)
    
    score = tf.nn.tanh(self.W1(features) + self.W2(hidden_with_time_axis))
    
    
    attention_weights = tf.nn.softmax(self.V(score), axis=1)
    
    context_vector = attention_weights * features
    context_vector = tf.reduce_sum(context_vector, axis = 1)
    return context_vector, attention_weights

# %%
class CNN_Encoder(tf.keras.Model):
  def __init__(self, embedding_dim):
    super(CNN_Encoder, self).__init__()
    
    self.fc = tf.keras.layers.Dense(embedding_dim)
    
  def call(self,x):
    x = self.fc(x)
    x = tf.nn.relu(x)
    return x

# %%
class RNN_Decoder(tf.keras.Model):
  def __init__(self, embedding_dim, units, vocab_size):
    super(RNN_Decoder, self).__init__()
    self.units = units
    
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = gru(self.units)
    self.fc1 = tf.keras.layers.Dense(self.units)
    self.fc2 = tf.keras.layers.Dense(vocab_size)
    
    self.attention = BahdanauAttention(self.units)
    
  def call(self, x, features, hidden):
    context_vector, attention_weights = self.attention(features, hidden)
    
    x = self.embedding(x)
    
    x = tf.concat([tf.expand_dims(context_vector,1),x], axis = -1)
    
    output, state = self.gru(x)
    x = self.fc1(output)
    x = tf.reshape(x, (-1, x.shape[2]))
    x = self.fc2(x)
    
    return x, state, attention_weights
  def reset_state(self, batch_size):
    return tf.zeros((batch_size, self.units))

# %%
encoder = CNN_Encoder(embedding_dim)
decoder = RNN_Decoder(embedding_dim, units, vocab_size)

# %%
optimizer = tf.train.AdamOptimizer()

def loss_function(real, pred):
  mask = 1 - np.equal(real, 0)
  loss_ = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=real, logits=pred)
  return tf.reduce_mean(loss_)

# %%
loss_plot = []
print(tokenizer.word_index)
# Out:
# {'<unk>': 1, 'a': 2, '<start>': 3, '<end>': 4, 'on': 5, 'of': 6, 'the': 7, 'in': 8, 'with': 9, 'and': 10, 'is': 11, 'man': 12, 'to': 13, 'sitting': 14, 'an': 15, 'two': 16, 'people': 17, 'standing': 18, 'at': 19, 'are': 20, 'white': 21, 'next': 22, 'woman': 23, 'street': 24, 'table': 25, 'that': 26, 'holding': 27, 'some': 28, 'person': 29, 'large': 30, 'it': 31, 'down': 32, 'top': 33, 'group': 34, 'field': 35, 'up': 36, 'small': 37, 'tennis': 38, 'front': 39, 'near': 40, 'black': 41, 'his': 42, 'plate': 43, 'room': 44, 'riding': 45, 'dog': 46, 'train': 47, 'by': 48, 'cat': 49, 'young': 50, 'red': 51, 'baseball': 52, 'water': 53, 'has': 54, 'walking': 55, 'playing': 56, 'bathroom': 57, 'sign': 58, 'while': 59, 'blue': 60, 'grass': 61, 'food': 62, 'kitchen': 63, 'green': 64, 'bus': 65, 'there': 66, 'parked': 67, 'looking': 68, 'other': 69, 'pizza': 70, 'side': 71, 'bed': 72, 'snow': 73, 'building': 74, 'beach': 75, 'ball': 76, 'boy': 77, 'for': 78, 'couple': 79, 'men': 80, 'three': 81, 'toilet': 82, 'city': 83, 'road': 84, 'flying': 85, 'skateboard': 86, 'wearing': 87, 'player': 88, 'her': 89, 'out': 90, 'game': 91, 'laying': 92, 'several': 93, 'over': 94, 'clock': 95, 'girl': 96, 'sits': 97, 'from': 98, 'picture': 99, 'their': 100, 'one': 101, 'bear': 102, 'wooden': 103, 'around': 104, 'through': 105, 'cake': 106, 'laptop': 107, 'bench': 108, 'brown': 109, 'area': 110, 'eating': 111, 'frisbee': 112, 'yellow': 113, 'sink': 114, 'phone': 115, 'board': 116, 'horse': 117, 'computer': 118, 'giraffe': 119, 'outside': 120, 'as': 121, 'desk': 122, 'truck': 123, 'living': 124, 'each': 125, 'close': 126, 'umbrella': 127, 'motorcycle': 128, 'air': 129, 'window': 130, 'car': 131, 'covered': 132, 'many': 133, 'wall': 134, 'trees': 135, 'elephant': 136, 'tree': 137, 'park': 138, 'open': 139, 'very': 140, 'this': 141, 'behind': 142, 'old': 143, 'fire': 144, 'filled': 145, 'stop': 146, 'little': 147, 'under': 148, 'into': 149, 'court': 150, 'together': 151, 'sky': 152, 'bat': 153, 'surfboard': 154, 'its': 155, 'child': 156, 'bowl': 157, 'kite': 158, 'boat': 159, 'inside': 160, 'sheep': 161, 'airplane': 162, 'background': 163, 'skis': 164, 'big': 165, 'back': 166, 'chair': 167, 'couch': 168, 'glass': 169, 'photo': 170, 'bunch': 171, 'stands': 172, 'view': 173, 'hydrant': 174, 'cell': 175, 'shirt': 176, 'mirror': 177, 'ocean': 178, 'traffic': 179, 'light': 180, 'bird': 181, 'plane': 182, 'women': 183, 'different': 184, 'sandwich': 185, 'teddy': 186, 'zebra': 187, 'counter': 188, 'stand': 189, 'orange': 190, 'hand': 191, 'another': 192, 'parking': 193, 'fence': 194, 'sidewalk': 195, 'horses': 196, 'tall': 197, 'wave': 198, 'giraffes': 199, 'lot': 200, 'baby': 201, 'vase': 202, 'cars': 203, 'tracks': 204, 'racket': 205, 'vegetables': 206, 'flowers': 207, 'elephants': 208, 'bananas': 209, 'floor': 210, 'grassy': 211, 'tie': 212, 'ground': 213, 'zebras': 214, 'day': 215, 'off': 216, 'full': 217, 'being': 218, 'middle': 219, 'dirt': 220, 'tower': 221, 'ready': 222, 'along': 223, 'hill': 224, 'signs': 225, 'wine': 226, 'across': 227, 'bike': 228, 'station': 229, 'long': 230, 'slope': 231, 'four': 232, 'taking': 233, 'grazing': 234, 'image': 235, 'sit': 236, 'head': 237, 'luggage': 238, 'piece': 239, 'beside': 240, 'skiing': 241, 'during': 242, 'cows': 243, 'stuffed': 244, 'driving': 245, 'hanging': 246, 'pink': 247, 'skate': 248, 'glasses': 249, 'them': 250, 'doing': 251, 'double': 252, 'hat': 253, 'above': 254, 'fruit': 255, 'broccoli': 256, 'wii': 257, 'suit': 258, 'herd': 259, 'corner': 260, 'refrigerator': 261, 'display': 262, 'snowy': 263, 'cow': 264, 'hot': 265, 'cutting': 266, 'going': 267, 'holds': 268, 'pair': 269, 'buildings': 270, 'trick': 271, 'ski': 272, 'talking': 273, 'mountain': 274, 'camera': 275, 'empty': 276, 'keyboard': 277, 'watching': 278, 'various': 279, 'kites': 280, 'swinging': 281, 'pole': 282, 'posing': 283, 'looks': 284, 'door': 285, 'television': 286, 'smiling': 287, 'oven': 288, 'airport': 289, 'getting': 290, 'umbrellas' ...

# %%
EPOCHS = 20
for epoch in range(EPOCHS):
  start = time.time()
  total_loss = 0
  
  for (batch, (img_tensor, target)) in enumerate(dataset):
    loss = 0
    
    hidden = decoder.reset_state(batch_size=target.shape[0])
    
    dec_input = tf.expand_dims([tokenizer.word_index['start']]*BATCH_SIZE,1)
    
    with tf.GradientTape() as tape:
      features = encoder(img_tensor)
      
      for i in range(1, target.shape[1]):
        predictions, hidden, _ = decoder(dec_input, features, hidden)
        
        loss += loss_function(target[:,i], predictions)
        
        dec_input = tf.expand_dims(target[:,i],1)
    total_loss += (loss/int(target.shape[1]))
    variables = encoder.variables + decoder.variables
    gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables), tf.train.get_or_create_global_step())
    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch+1,batch,loss.numpy()/int(target.shape[1])))
  loss_plot.append(total_loss/len(cap_vector))
  print('Epoch {} Loss {:.6f}'.format(epoch+1, total_loss/len(cap_vector)))
  print('Time Taken for 1 epoch {} sec\n'.format(time.time()-start))
# Out:
# Epoch 1 Batch 0 Loss 9.3416
# Epoch 1 Batch 100 Loss 1.3589
# Epoch 1 Batch 200 Loss 1.0762
# Epoch 1 Batch 300 Loss 0.9796
# Epoch 1 Batch 400 Loss 1.0925
# Epoch 1 Batch 500 Loss 0.9782
# Epoch 1 Batch 600 Loss 0.9555
# Epoch 1 Batch 700 Loss 0.8678
# Epoch 1 Batch 800 Loss 0.8664
# Epoch 1 Batch 900 Loss 0.8756
# Epoch 1 Batch 1000 Loss 0.8135
# Epoch 1 Batch 1100 Loss 0.7230
# Epoch 1 Batch 1200 Loss 0.7477
# Epoch 1 Loss 0.012455
# Time Taken for 1 epoch 1281.4434235095978 sec
#
# Epoch 2 Batch 0 Loss 0.8208
# Epoch 2 Batch 100 Loss 0.7971
# Epoch 2 Batch 200 Loss 0.7447
# Epoch 2 Batch 300 Loss 0.7713
# Epoch 2 Batch 400 Loss 0.6932
# Epoch 2 Batch 500 Loss 0.6448
# Epoch 2 Batch 600 Loss 0.7655
# Epoch 2 Batch 700 Loss 0.6813
# Epoch 2 Batch 800 Loss 0.6919
# Epoch 2 Batch 900 Loss 0.7302
# Epoch 2 Batch 1000 Loss 0.6961
# Epoch 2 Batch 1100 Loss 0.6950
# Epoch 2 Batch 1200 Loss 0.6817
# Epoch 2 Loss 0.009026
# Time Taken for 1 epoch 1276.7415833473206 sec
#
# Epoch 3 Batch 0 Loss 0.6776
# Epoch 3 Batch 100 Loss 0.6989
# Epoch 3 Batch 200 Loss 0.6913
# Epoch 3 Batch 300 Loss 0.6125
# Epoch 3 Batch 400 Loss 0.6549
# Epoch 3 Batch 500 Loss 0.6200
# Epoch 3 Batch 600 Loss 0.6908
# Epoch 3 Batch 700 Loss 0.5885
# Epoch 3 Batch 800 Loss 0.7295
# Epoch 3 Batch 900 Loss 0.6197
# Epoch 3 Batch 1000 Loss 0.6456
# Epoch 3 Batch 1100 Loss 0.6390
# Epoch 3 Batch 1200 Loss 0.6391
# Epoch 3 Loss 0.008319
# Time Taken for 1 epoch 1262.257202386856 sec
#
# Epoch 4 Batch 0 Loss 0.5865
# Epoch 4 Batch 100 Loss 0.6964
# Epoch 4 Batch 200 Loss 0.5968
# Epoch 4 Batch 300 Loss 0.6489
# Epoch 4 Batch 400 Loss 0.6786
# Epoch 4 Batch 500 Loss 0.6280
# Epoch 4 Batch 600 Loss 0.6308
# Epoch 4 Batch 700 Loss 0.6023
# Epoch 4 Batch 800 Loss 0.6527
# Epoch 4 Batch 900 Loss 0.6815
# Epoch 4 Batch 1000 Loss 0.6417
# Epoch 4 Batch 1100 Loss 0.6309
# Epoch 4 Batch 1200 Loss 0.5664
# Epoch 4 Loss 0.007904
# Time Taken for 1 epoch 1290.5309159755707 sec
#
# Epoch 5 Batch 0 Loss 0.5916
# Epoch 5 Batch 100 Loss 0.6411
# Epoch 5 Batch 200 Loss 0.6598
# Epoch 5 Batch 300 Loss 0.6768
# Epoch 5 Batch 400 Loss 0.6692
# Epoch 5 Batch 500 Loss 0.5920
# Epoch 5 Batch 600 Loss 0.6166
# Epoch 5 Batch 700 Loss 0.6293
# Epoch 5 Batch 800 Loss 0.5630
# Epoch 5 Batch 900 Loss 0.6229
# Epoch 5 Batch 1000 Loss 0.6751
# Epoch 5 Batch 1100 Loss 0.6365
# Epoch 5 Batch 1200 Loss 0.5932
# Epoch 5 Loss 0.007596
# Time Taken for 1 epoch 1277.9772453308105 sec
#
# Epoch 6 Batch 0 Loss 0.6090
# Epoch 6 Batch 100 Loss 0.6643
# Epoch 6 Batch 200 Loss 0.6387
# Epoch 6 Batch 300 Loss 0.6065
# Epoch 6 Batch 400 Loss 0.5500
# Epoch 6 Batch 500 Loss 0.5663
# Epoch 6 Batch 600 Loss 0.5802
# Epoch 6 Batch 700 Loss 0.5872
# Epoch 6 Batch 800 Loss 0.6129
# Epoch 6 Batch 900 Loss 0.6190
# Epoch 6 Batch 1000 Loss 0.6197
# Epoch 6 Batch 1100 Loss 0.5337
# Epoch 6 Batch 1200 Loss 0.6414
# Epoch 6 Loss 0.007330
# Time Taken for 1 epoch 1264.1820483207703 sec
#
# Epoch 7 Batch 0 Loss 0.5605
# Epoch 7 Batch 100 Loss 0.5767
# Epoch 7 Batch 200 Loss 0.5361
# Epoch 7 Batch 300 Loss 0.5659
# Epoch 7 Batch 400 Loss 0.5575
# Epoch 7 Batch 500 Loss 0.5594
# Epoch 7 Batch 600 Loss 0.5262
# Epoch 7 Batch 700 Loss 0.5046
# Epoch 7 Batch 800 Loss 0.5541
# Epoch 7 Batch 900 Loss 0.5282
# Epoch 7 Batch 1000 Loss 0.5827
# Epoch 7 Batch 1100 Loss 0.5510
# Epoch 7 Batch 1200 Loss 0.5523
# Epoch 7 Loss 0.007078
# Time Taken for 1 epoch 1274.1697928905487 sec
#
# Epoch 8 Batch 0 Loss 0.5675
# Epoch 8 Batch 100 Loss 0.5897
# Epoch 8 Batch 200 Loss 0.5916
# Epoch 8 Batch 300 Loss 0.6032
# Epoch 8 Batch 400 Loss 0.5905
# Epoch 8 Batch 500 Loss 0.5197
# Epoch 8 Batch 600 Loss 0.5567
# Epoch 8 Batch 700 Loss 0.5251
# Epoch 8 Batch 800 Loss 0.5545
# Epoch 8 Batch 900 Loss 0.5687
# Epoch 8 Batch 1000 Loss 0.6052
# Epoch 8 Batch 1100 Loss 0.5829
# Epoch 8 Batch 1200 Loss 0.5358
# Epoch 8 Loss 0.006852
# Time Taken for 1 epoch 1271.5941247940063 sec
#
# Epoch 9 Batch 0 Loss 0.5272
# Epoch 9 Batch 100 Loss 0.5443
# Epoch 9 Batch 200 Loss 0.4805
# Epoch 9 Batch 300 Loss 0.5559
# Epoch 9 Batch 400 Loss 0.5134
# Epoch 9 Batch 500 Loss 0.5061
# Epoch 9 Batch 600 Loss 0.5336
# Epoch 9 Batch 700 Loss 0.5121
# Epoch 9 Batch 800 Loss 0.5188
# Epoch 9 Batch 900 Loss 0.5704
# Epoch 9 Batch 1000 Loss 0.5306
# Epoch 9 Batch 1100 Loss 0.5226
# Epoch 9 Batch 1200 Loss 0.5278
# Epoch 9 Loss 0.006615
# Time Taken for 1 epoch 1265.5533044338226 sec
#
# Epoch 10 Batch 0 Loss 0.5387
# Epoch 10 Batch 100 Loss 0.5297
# Epoch 10 Batch 200 Loss 0.4850
# Epoch 10 Batch 300 Loss 0.5360
# Epoch 10 Batch 400 Loss 0.4792
# Epoch 10 Batch 500 Loss 0.5057
# Epoch 10 Batch 600 Loss 0.4667
# Epoch 10 Batch 700 Loss 0.4918
# Epoch 10 Batch 800 Loss 0.4796
# Epoch 10 Batch 900 Loss 0.5102
# Epoch 10 Batch 1000 Loss 0.5366
# Epoch 10 Batch 1100 Loss 0.5475
# Epoch 10 Batch 1200 Loss 0.4914
# Epoch 10 Loss 0.006393
# Time Taken for 1 epoch 1272.86985039711 sec
#
# Epoch 11 Batch 0 Loss 0.5217
# Epoch 11 Batch 100 Loss 0.5173
# Epoch 11 Batch 200 Loss 0.5001
# Epoch 11 Batch 300 Loss 0.4734
# Epoch 11 Batch 400 Loss 0.4603
# Epoch 11 Batch 500 Loss 0.4809
# Epoch 11 Batch 600 Loss 0.4570
# Epoch 11 Batch 700 Loss 0.4815
# Epoch 11 Batch 800 Loss 0.4816
# Epoch 11 Batch 900 Loss 0.4812
# Epoch 11 Batch 1000 Loss 0.5700
# Epoch 11 Batch 1100 Loss 0.4857
# Epoch 11 Batch 1200 Loss 0.4835
# Epoch 11 Loss 0.006180
# Time Taken for 1 epoch 1269.5775771141052 sec
#
# Epoch 12 Batch 0 Loss 0.4272
# Epoch 12 Batch 100 Loss 0.4819
# Epoch 12 Batch 200 Loss 0.4456
# Epoch 12 Batch 300 Loss 0.4753
# Epoch 12 Batch 400 Loss 0.4752
# Epoch 12 Batch 500 Loss 0.4328
# Epoch 12 Batch 600 Loss 0.4945
# Epoch 12 Batch 700 Loss 0.5062
# Epoch 12 Batch 800 Loss 0.3973
# Epoch 12 Batch 900 Loss 0.4787
# Epoch 12 Batch 1000 Loss 0.5219
# Epoch 12 Batch 1100 Loss 0.4116
# Epoch 12 Batch 1200 Loss 0.4512
# Epoch 12 Loss 0.005976
# Time Taken for 1 epoch 1270.2852046489716 sec
#
# Epoch 13 Batch 0 Loss 0.4685
# Epoch 13 Batch 100 Loss 0.4787
# Epoch 13 Batch 200 Loss 0.4543
# Epoch 13 Batch 300 Loss 0.4560
# Epoch 13 Batch 400 Loss 0.5001
# Epoch 13 Batch 500 Loss 0.5034
# Epoch 13 Batch 600 Loss 0.5327
# Epoch 13 Batch 700 Loss 0.4633
# Epoch 13 Batch 800 Loss 0.4983
# Epoch 13 Batch 900 Loss 0.4703
# Epoch 13 Batch 1000 Loss 0.4517
# Epoch 13 Batch 1100 Loss 0.4186
# Epoch 13 Batch 1200 Loss 0.4641
# Epoch 13 Loss 0.005786
# Time Taken for 1 epoch 1275.4710981845856 sec
#
# Epoch 14 Batch 0 Loss 0.4645
# Epoch 14 Batch 100 Loss 0.4134
# Epoch 14 Batch 200 Loss 0.4591
# Epoch 14 Batch 300 Loss 0.4198
# Epoch 14 Batch 400 Loss 0.4211
# Epoch 14 Batch 500 Loss 0.4487
# Epoch 14 Batch 600 Loss 0.4565
# Epoch 14 Batch 700 Loss 0.4453
# Epoch 14 Batch 800 Loss 0.4397
# Epoch 14 Batch 900 Loss 0.4851
# Epoch 14 Batch 1000 Loss 0.4033
# Epoch 14 Batch 1100 Loss 0.4595
# Epoch 14 Batch 1200 Loss 0.4035
# Epoch 14 Loss 0.005595
# Time Taken for 1 epoch 1265.5041146278381 sec
#
# Epoch 15 Batch 0 Loss 0.4859
# Epoch 15 Batch 100 Loss 0.4587
# Epoch 15 Batch 200 Loss 0.4280
# Epoch 15 Batch 300 Loss 0.4465
# Epoch 15 Batch 400 Loss 0.4226
# Epoch 15 Batch 500 Loss 0.4208
# Epoch 15 Batch 600 Loss 0.4193
# Epoch 15 Batch 700 Loss 0.4093
# Epoch 15 Batch 800 Loss 0.4816
# Epoch 15 Batch 900 Loss 0.4124
# Epoch 15 Batch 1000 Loss 0.4456
# Epoch 15 Batch 1100 Loss 0.4076
# Epoch 15 Batch 1200 Loss 0.3897
# Epoch 15 Loss 0.005422
# Time Taken for 1 epoch 1270.0025436878204 sec
#
# Epoch 16 Batch 0 Loss 0.4536
# Epoch 16 Batch 100 Loss 0.4069
# Epoch 16 Batch 200 Loss 0.4264
# Epoch 16 Batch 300 Loss 0.3975
# Epoch 16 Batch 400 Loss 0.4159
# Epoch 16 Batch 500 Loss 0.4059
# Epoch 16 Batch 600 Loss 0.4606
# Epoch 16 Batch 700 Loss 0.4541
# Epoch 16 Batch 800 Loss 0.4369
# Epoch 16 Batch 900 Loss 0.4078
# Epoch 16 Batch 1000 Loss 0.3986
# Epoch 16 Batch 1100 Loss 0.4398
# Epoch 16 Batch 1200 Loss 0.3875
# Epoch 16 Loss 0.005263
# Time Taken for 1 epoch 1274.3558864593506 sec
#
# Epoch 17 Batch 0 Loss 0.4717
# Epoch 17 Batch 100 Loss 0.4061
# Epoch 17 Batch 200 Loss 0.4242
# Epoch 17 Batch 300 Loss 0.4156
# Epoch 17 Batch 400 Loss 0.4011
# Epoch 17 Batch 500 Loss 0.3994
# Epoch 17 Batch 600 Loss 0.3979
# Epoch 17 Batch 700 Loss 0.3929

# %%
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2c9c80a3f2d9> in <module>()
# ----> 1 plt.plot(loss_plot)
#       2 plt.xlabel('Epochs')
#       3 plt.ylabel('Loss')
#       4 plt.title('Loss Plot')
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
def evaluate(image):
  attention_plot = np.zeros((max_length, attention_features_shape))
  
  hidden = decoder.reset_state(batch_size=1)
  
  temp_input = tf.expand_dims(load_image(image)[0], 0)
  img_tensor_val = image_features_extract_model(temp_input)
  img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))
  
  features = encoder(img_tensor_val)
  
  dec_input = tf.expand_dims([tokenizer.word_index['<start>']],0)
  result = []
  
  for i in range(max_length):
    predictions, hidden, attention_weights = decoder(dec_input, features, hidden)
    
    attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()
    
    predicted_id = tf.argmax(predictions[0]).numpy()
    result.append(tokenizer.index_word[predicted_id])
    
    if tokenizer.index_word[predicted_id] == '<end>':
      return result, attention_plot
    dec_input = tf.expand_dims([predicted_id], 0)
    
  attention_plot = attention_plot[:len(result),:]
  return result, attention_plot

# %%
def reevaluate(image):
  hidden = decoder.reset_state(batch_size=1)
  
  temp_input = tf.expand_dims(load_image(image)[0], 0)
  img_tensor_val = image_features_extract_model(temp_input)
  img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))
  
  features = encoder(img_tensor_val)
  
  dec_input = tf.expand_dims([tokenizer.word_index['<start>']],0)
  result = []
  
  for i in range(max_length):
    predictions, hidden, attention_weights = decoder(dec_input, features, hidden)
    predicted_id = tf.argmax(predictions[0]).numpy()
    result.append(tokenizer.index_word[predicted_id])
    if tokenizer.index_word[predicted_id] == '<end>':
      return result
    dec_input = tf.expand_dims([predicted_id], 0)
  return result

# %%
def plot_attention(image, result, attention_plot):
  temp_image = np.array(Image.open(image))
  
  fig = plt.figure(figsize=(10,10))
  
  len_result = len(result)
  for l in range(len_result):
    temp_att = np.resize(attention_plot[l], (8,8))
    ax = fig.add_subplot(len_result//2, len_result//2, l+1)
    ax.set_title(result[l])
    img = ax.imshow(temp_image)
    ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())
  plt.tight_layout()
  plt.show()

# %%
rid = np.random.randint(0, len(img_name_val))

image = img_name_val[rid]


real_caption = ' '.join([tokenizer.index_word[i] for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print('Real Caption:', real_caption)
print('Predicted Caption:', ' '.join(result))
plot_attention(image,result,attention_plot)

Image.open(img_name_val[rid])
# Out:
# Real Caption: <start> a black cat and a black cat statue in a window sill <end>
# Predicted Caption: sitting next to a dog in a eatery <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F7F589879B0>

# %%
reals=[]
predicted=[]

for j in range(len(img_name_val)):
  image = img_name_val[j]
  real_cap = [tokenizer.index_word[i] for i in cap_val[j] if i not in [0,3,4]] #0:pad, 3: start, 4:end
  result= reevaluate(image)
  reals.append(real_cap)
  predicted.append(result[:-1])
  if j % 100 == 0:
    print(j)

# %%
predicted[:5]
# Out:
# [['sitting', 'on', 'the', 'edge', 'of', 'a', 'park'],
#  ['carrying', 'a', 'surfboard', 'on', 'a', 'river'],
#  ['that', 'is', 'watching', 'a', 'baseball', 'during', 'a', 'game'],
#  ['photo',
#   'of',
#   'a',
#   'baseball',
#   'players',
#   'are',
#   'playing',
#   'a',
#   'game',
#   'tries',
#   'to',
#   'catch',
#   'it'],
#  ['on', 'a', 'sandy', 'shore', 'of', 'grass', 'covered', 'in', 'shore']]

# %%
from nltk.translate.bleu_score import sentence_bleu
scores=[]
for i in range(len(reals)):
  score=np.zeros(4)
  reference = [reals[i]]
  candidate = predicted[i]
  score[0] = sentence_bleu(reference, candidate,weights = (1,0,0,0))
  score[1] = sentence_bleu(reference, candidate,weights = (0.5,0.5,0,0))
  score[2] = sentence_bleu(reference, candidate,weights = (0.33,0.33,0.33,0))
  score[3] = sentence_bleu(reference, candidate,weights = (0.25,0.25,0.25,0.25))
  scores.append(score)
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
import numpy as np
scores = np.array(scores)
scores.shape
# Out:
# (6000, 4)

# %%
for i in range(scores.shape[1]):
  print(np.sum(scores[:,i]/scores.shape[0]))
# Out:
# 0.1950259685192839
# 0.2454415888572842
# 0.31596459307521124
# 0.36704276601526004

# %%
import pickle
truth_file = open('ground_truth_6000_423.pickle', 'wb')
pickle.dump(reals, truth_file)
truth_file.close()
pred_file = open('predicted_val_6000_423.pickle','wb')
pickle.dump(predicted, pred_file)
pred_file.close()

# %%
image_path = '/content/sf.jpg'

result, attention_plot = evaluate(image_path)
print('Prediction Caption', ' '. join(result))
plot_attention(image_path, result, attention_plot)

Image.open(image_path)
# Out:
# Prediction Caption a surfer wearing a surf board in low end
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x426 at 0x7FD6E5ECD7B8>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-229-8e3f8d55d558> in <module>()
# ----> 1 dataset.info
#
# AttributeError: 'DatasetV1Adapter' object has no attribute 'info'
